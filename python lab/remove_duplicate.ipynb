# %%
n=int(input("Enter the number of elements :"))
l=[]
print("Enter the elements ")
for i in range(n):
  data=input()
  l.append(data)
l=list(set(l))
print("New list",l)
# Out:
# Enter the number of elements :5
# Enter the elements
# 1
# 2
# 1
# 3
# 1
# New list ['2', '3', '1']

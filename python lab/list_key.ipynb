# %%
print("List")
n=int(input("Enter the number of elements :"))
l=[]
for i in range(n):
  data=input()
  l.append(data)
key=input("\nEnter the key value :")
if key in l:
  print("Found")
else:
  print("Not found")
# Out:
# List
# Enter the number of elements :3
# 1
#
# 2
#
# Enter the key value :4
# Not found
# ['1', '', '2']

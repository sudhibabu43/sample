# %%
name=input("Enter a string : ")

left = 0
right = len(name) - 1
while left < right:
    if name[left] != name[right]:
      print("No")
      break
    left += 1
    right -= 1
else:
    print("Yes")
# Out:
# Enter a string : malayalam
# Yes

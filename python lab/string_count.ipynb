# %%
string=input("Enter a string :")
length=len(string)
n=0
for i in range(length):
  if string[i]=='a' or string[i]=='A' or string[i]=='a' or string[i]=='e' or string[i]=='i' or string[i]=='I' or string[i]=='o' or string[i]=='O' or string[i]=='u' or string[i]=='U':
    n=n+1
print(n)
# Out:
# Enter a string :elephant
# 3

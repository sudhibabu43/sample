# %%
n=int(input("Enter the number of elements :"))
l=[]
a=[]
print("Enter the elements ")
for i in range(n):
  data=input()
  l.append(data)
a=set(l)
for i in a:
  count=0
  for j in l:
      if i==j:
        count=count+1
  print(count,"=",i)

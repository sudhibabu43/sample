# %%
n=int(input("Enter the number of elements :"))
l=[]
a=[]
b=[]
print("Enter the elements ")
for i in range(n):
  data=input()
  l.append(data)
a=set(l)
for i in a[1:]:
  count=0
  for j in l:
    if(i<j):
      count=count+1
  b.append(count)
print(b)
# Out:
# Enter the number of elements :5
# Enter the elements
# 1
# 4
# 3
# 5
# 2
# [1, 0, 4, 3, 2]
